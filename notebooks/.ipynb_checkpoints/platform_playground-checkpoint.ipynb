# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %reset

# %%
import numpy as np
import pandas as pd

# %%
array = pd.Series(np.random.default_rng().uniform(-10000, 10000, (500000,)))
array.to_csv("../data/uniform_distribution.csv")

# %%
from algo.codec.kmeans_1d import KMeansLinearCompression
from algo.process.normalize import NormalizeProcessing
from scaffold import Scaffold
import numpy as np
np.seterr(all='warn')
#np.seterr(all='raise') # something breaks on the large dataset
benchmarks = []
Algos = [KMeansLinearCompression(max_rmse=0.8), KMeansLinearCompression(max_rmse=0.005), KMeansLinearCompression(max_rmse=0.01), KMeansLinearCompression(max_rmse=0.05), KMeansLinearCompression(max_rmse=0.1), KMeansLinearCompression(max_rmse=0.3), KMeansLinearCompression(max_rmse=0.5)]
Processes = [NormalizeProcessing()]
for algo in Algos:
    for proc in Processes:
        a = Scaffold(algo, proc, "../data/sample_dataset.csv")
        a.start("test", logs=True)
        print(a.benchmark)
        benchmarks.append(a.benchmark)
        print("---------------------")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from algo.codec.kmeans_1d import KMeansLinearCompression
#       2 from algo.process.normalize import NormalizeProcessing
#       3 from scaffold import Scaffold
#
# ModuleNotFoundError: No module named 'algo'

# %%
from scaffold.json import json_scaffold
json_scaffold("plug_config.json")

# %%
from algo.codec.zstd import ZstdLibraryCompressionAlgorithm
from algo.codec.kmeans_1d import KMeansLinearCompression
from algo.process.normalize import NormalizeProcessing
from scaffold import Scaffold
import numpy as np
np.seterr(all='warn')
#np.seterr(all='raise') # something breaks on the large dataset
Algos = [ZstdLibraryCompressionAlgorithm()]
Processes = [NormalizeProcessing()]
for algo in Algos:
    for proc in Processes:
        a = Scaffold(algo, proc, "../data/sample_dataset.csv")
        a.start("test", logs=True)
        print(a.benchmark)
        benchmarks.append(a.benchmark)
        print("---------------------")
# Out:
# ../data/sample_dataset.csv_compressed 9980233 4729772
# Function preprocess_and_compress took 1.8293559551239014 seconds to execute.
# Index(['end_epoch', 'start_epoch', 'value_1', 'value_2', 'value_3', 'value_4',
#        'value_5', 'value_6', 'value_7', 'value_8', 'value_9', 'value_10',
#        'value_11', 'value_14', 'value_15', 'value_16', 'value_17', 'value_18',
#        'value_19', 'value_20', 'value_21', 'value_22', 'value_23', 'value_24',
#        'value_25', 'value_26', 'time'],
#       dtype='object')
# Function decompress_and_postprocess took 0.8611800670623779 seconds to execute.
# Function test took 2.6915335655212402 seconds to execute.
# {'name': 'ZstdLibraryCompressionAlgorithm', 'table_path': '../data/sample_dataset.csv', 'isLossLess': True, 'isLearning': False, 'compression_rate': 0.4739139857756828, 'preprocess_and_compress_time': 1.8293559551239014, 'loss_rate': 0.0, 'decompress_and_postprocess_time': 0.8611800670623779, 'test_time': 2.6915335655212402}
# ---------------------

# %%
benchmarks_all = benchmarks.copy()

# %%
from plot import plot_benchmarks

plot_benchmarks(benchmarks, "loss_rate")
for i in benchmarks:
    print(i["loss_rate"])
print(benchmarks)
# Out:
# 0.009986349875437402
# [{'name': 'KMeansLinearCompression', 'table_path': '../data/uniform_distribution.csv', 'isLossLess': False, 'isLearning': False, 'compression_rate': 0.07674311830116268, 'preprocess_and_compress_time': 1751.0396492481232, 'loss_rate': 0.009986349875437402, 'decompress_and_postprocess_time': 1.889927864074707, 'test_time': 1752.9295771121979}]

# %%
plot_benchmarks(benchmarks, "compression_rate")

# %%
from plot import plot_scatter

plot_scatter(benchmarks, "test_time")

# %%
from plot import plot_hist

plot_hist(benchmarks, "test_time")

# %%
from generator.normal_multivariate import NormalMultivariateDistributionGenerator
gen = NormalMultivariateDistributionGenerator()
gen.gen([0,0], [[1, 0], [0, 1]], (2,))

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("../data/smoke_detection_iot.csv").iloc[:5, [0, 2, 3, 6, 7, 8, 14]]
np_table = df.to_numpy()

# %%
df

# %%
np_table = (np_table - vecT(np.mean(np_table, axis=0)).T) / vecT(np.std(np_table, axis=0)).T
# Out:
# array([[-1.4, -0.5, -1. ],
#        [-0.7, -1.3, -0.9],
#        [ 0. , -0.6, -0.4],
#        [ 0.7,  1.1,  0.9],
#        [ 1.4,  1.3,  1.5]])

# %%
def vecT(vec):
    return np.array(vec)[np.newaxis].T

# %%
np_table = np_table.T

# %%
np_table

# %%
covy = np_table.T @ np_table / np_table.shape[0]
# Out:
# array([[-1.4, -0.7,  0. ,  0.7,  1.4],
#        [-0.5, -1.3, -0.6,  1.1,  1.3],
#        [-1. , -0.9, -0.4,  0.9,  1.5]])

# %%
covy

# %%
eigvals, eigvecs = np.linalg.eig(covy)
# Out:
# array([[1. , 0.8, 1. ],
#        [0.8, 1. , 1. ],
#        [1. , 1. , 1. ]])

# %%
eigvecs = eigvecs[:, :3]

# %%
eigvals = eigvals[:3]
# Out:
# array([[ 0.70137266, -0.56980625],
#        [-0.71272483, -0.56903704],
#        [ 0.00998552, -0.59288927]])

# %%
eigvecs

# %%
vecT(eigvals).T

# %%
np_table
# Out:
# array([[ 0.7, -0.6],
#        [-0.7, -0.6],
#        [ 0. , -0.6]])

# %%
compressed = np_table @ eigvecs
# Out:
# array([[0.2, 2.8]])

# %%
compressed

# %%
eigvecs.T

# %%
compressed.T @ compressed
# Out:
# array([[-0.6283503 ,  0.40632888,  0.38897577, -0.27750802,  0.11055367],
#        [ 1.69893069,  1.67759817,  0.56927194, -1.54783845, -2.39796236]])

# %%
decompressed = compressed @ eigvecs.T
# Out:
# array([[ 3.54269976e+00, -6.17412708e-18,  2.18893506e-16],
#        [-6.17412708e-18,  2.00115553e-01,  3.80474967e-17],
#        [ 2.18893506e-16,  3.80474967e-17,  7.18468923e-03]])

# %%
eigvecs.T

# %%
np_table
# Out:
# array([[-0.56980625, -0.56903704, -0.59288927]])

# %%
np.linalg.pinv(eigvecs)
# Out:
# array([[-1.41421356, -0.52412801, -1.00331504],
#        [-0.70710678, -1.27887526, -0.92252794],
#        [ 0.        , -0.55179117, -0.43057336],
#        [ 0.70710678,  1.09750364,  0.87774292],
#        [ 1.41421356,  1.2572908 ,  1.47867342]])

# %%
denormalized = decompressed * vecT(np.std(np_table, axis=0)).T + vecT(np.mean(np_table, axis=0)).T
# Out:
# array([[-0.57451639,  0.58177401,  0.57573425]])

# %%
denormalized

# %%
# Out:
# array([[-1.4, -0.5, -1. ],
#        [-0.7, -1.2, -1. ],
#        [-0.1, -0.6, -0.3],
#        [ 0.7,  1.1,  0.9],
#        [ 1.4,  1.3,  1.4]])
